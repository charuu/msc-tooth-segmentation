# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '0'
import numpy as np
import nibabel as nib
from niwidgets import NiftiWidget
import tensorflow as tf
from tensorflow.keras.preprocessing.image import * 
from tensorflow import keras
from config import *
from modelIO import *
from model import *
from display import *
from dataAugmentation import *
from segmentation import *
from skimage.util import montage, crop
from skimage import data, color
from scipy import ndimage
from scipy import misc
from numpy import fliplr
from datetime import *
#import tensorflow.experimental.numpy as tnp
#print(device_lib.list_local_devices())
print(device_lib.list_local_devices())
tf.keras.backend.clear_session()
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/dicom/__init__.py:53: UserWarning:
# This code is using an older version of pydicom, which is no longer
# maintained as of Jan 2017.  You can access the new pydicom features and API
# by installing `pydicom` from PyPI.
# See 'Transitioning to pydicom 1.x' section at pydicom.readthedocs.org
# for more information.
#
#   warnings.warn(msg)
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 1743024364678197861
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4927016436840889475
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 4332460948881307375
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:XLA_GPU:1"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# ...

# %%
print(tf.__version__)
with tf.device('/device:gpu:2'):
    begin = datetime.now()
    current_time = begin.strftime("%H:%M:%S")
    print("Current Time =", current_time)
    #,'mandible-Right-Canine/iteration1','mandible-Right-Canine/iteration2','maxilla-Right-Molar/iteration1'
    train_segmentation('segmentation',unet3d(4),['mandible-Right-Molar/iteration1','mandible-Right-Molar/iteration2','mandible-Right-Canine/iteration1','mandible-Right-Canine/iteration3','maxilla-Right-Molar/iteration1','maxilla-Right-Molar/iteration2','mandible-Right-Molar/iteration3','mandible-Right-Molar/iteration4'])
    
    end = datetime.now()
    current_time = end.strftime("%H:%M:%S")
    print("Current Time =", current_time,"Difference",(end-begin))
# Out:
# 2.2.0
# Current Time = 19:42:18
# WARNING:tensorflow:From /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:AutoGraph could not transform <bound method PruneLowMagnitude.call of <tensorflow_model_optimization.python.core.sparsity.keras.pruning_wrapper.PruneLowMagnitude object at 0x7f5b311e9510>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
print(tf.__version__)
with tf.device('/device:gpu:1'):
    begin = datetime.now()
    current_time = begin.strftime("%H:%M:%S")
    print("Current Time =", current_time)
    
    train_segmentation('segmentation2d',unet3d(4),[])
    
    end = datetime.now()
    current_time = end.strftime("%H:%M:%S")
    print("Current Time =", current_time,"Difference",(end-begin))

# %%
m = train_segmentation('segmentation',unet3d(4),['molar'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b601db559871> in <module>
# ----> 1 m = train_segmentation('segmentation',unet3d(4),['molar'])
#
# NameError: name 'train_segmentation' is not defined

# %%
#mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2"])
#with mirrored_strategy.scope():
train_segmentation('segmentation',unet3d(4),['molar','canine','leftMolar','leftCanine'])

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:1","/gpu:2"])
with mirrored_strategy.scope():
    m = train_segmentation('classification_net',unet3d(4),['canine'])

# %% [markdown]
# ######
