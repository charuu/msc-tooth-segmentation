# %%
# Youtube: https://www.youtube.com/watch?v=CogGIdkDA8g

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow import keras
from config import *
from datetime import *

# %%
# Define constants
SEED = 909
BATCH_SIZE_TRAIN = 7
BATCH_SIZE_TEST = 7

IMAGE_HEIGHT = 40
IMAGE_WIDTH = 80
IMAGE_DEPTH = 40


IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)

data_dir = DATA_PATH+ '/sliced-output/'
#data_dir = '/home/jain0000/Desktop/data/'
data_dir_train = os.path.join(data_dir, 'train/')
# The images should be stored under: "data/slices/training/img/img"
#data_dir_train_image = os.path.join(data_dir_train, 'image')
data_dir_train_image = os.path.join(data_dir_train, 'image')

# The images should be stored under: "data/slices/training/mask/img"
data_dir_train_mask = os.path.join(data_dir_train, 'mask')
#data_dir_train_mask = os.path.join(data_dir_train, 'mask')

data_dir_test = os.path.join(data_dir, 'test/')
# The images should be stored under: "data/slices/test/img/img"
data_dir_test_image = os.path.join(data_dir_test, 'image')
#data_dir_test_image = os.path.join(data_dir_test, 'cropped_image')
# The images should be stored under: "data/slices/test/mask/img"
data_dir_test_mask = os.path.join(data_dir_test, 'mask')
#data_dir_test_mask = os.path.join(data_dir_test, 'mask')

NUM_TRAIN = 7
NUM_TEST = 7

NUM_OF_EPOCHS = 500

# %%
def create_segmentation_generator_train(img_path, msk_path, BATCH_SIZE):
    data_gen_args = dict(rescale=1./255
     #                    rotation_range=10,
      #                featurewise_center=True
#                      featurewise_std_normalization=True,
#                      rotation_range=30
#                      width_shift_range=0.2,
#                      height_shift_range=0.2,
#                      zoom_range=0.3
                        )
    datagen = ImageDataGenerator(**data_gen_args)
    
    img_generator = datagen.flow_from_directory(img_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    msk_generator = datagen.flow_from_directory(msk_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    return zip(img_generator, msk_generator)

# Remember not to perform any image augmentation in the test generator!
def create_segmentation_generator_test(img_path, msk_path, BATCH_SIZE):
    data_gen_args = dict(rescale=1./255)
    datagen = ImageDataGenerator(**data_gen_args)
    
    img_generator = datagen.flow_from_directory(img_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    msk_generator = datagen.flow_from_directory(msk_path, target_size=IMG_SIZE, class_mode=None, color_mode='grayscale', batch_size=BATCH_SIZE, seed=SEED)
    return zip(img_generator, msk_generator)

# %%
train_generator =  (pair for pair in create_segmentation_generator_train(data_dir_train_image, data_dir_train_mask, BATCH_SIZE_TRAIN))
test_generator =  (pair for pair in create_segmentation_generator_test(data_dir_test_image, data_dir_test_mask, BATCH_SIZE_TEST))
# Out:
# Found 4098 images belonging to 2 classes.
# Found 8834 images belonging to 2 classes.
# Found 2527 images belonging to 2 classes.
# Found 2670 images belonging to 2 classes.

# %%
def display(display_list):
    plt.figure(figsize=(15,15))
    
    title = ['Input Image', 'True Mask', 'Predicted Mask']
    
    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i+1)
        plt.title(title[i])
        plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap='gray')
    plt.show()

# %%
def show_dataset(datagen, num=2):
    for i in range(0,num):
        image,mask = next(datagen)
        display([image[0], mask[0]])

# %%
show_dataset(train_generator, 5)

# %%
def unet(n_levels, initial_features=32, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=1, out_channels=1):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs
    
    convpars = dict(kernel_size=kernel_size, activation='relu', padding='same')
    
    #downstream
    skips = {}
    for level in range(n_levels):
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
    #    x = keras.layers.BatchNormalization()(x)
        if level < n_levels - 1:
            skips[level] = x
            x = keras.layers.MaxPool2D(pooling_size)(x)
            
    # upstream
    for level in reversed(range(n_levels-1)):
        x = keras.layers.Conv2DTranspose(initial_features * 2 ** level, strides=pooling_size, **convpars)(x)
        x = keras.layers.Concatenate()([x, skips[level]])
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
 #       x = keras.layers.BatchNormalization()(x)
    x =  keras.layers.Dropout(0.8)(x)         
    # output
    activation = 'sigmoid' if out_channels == 1 else 'softmax'
    x = keras.layers.Conv2D(out_channels, kernel_size=1, activation=activation, padding='same')(x)
    
    return keras.Model(inputs=[inputs], outputs=[x], name=f'UNET-L{n_levels}-F{initial_features}')

# %%
EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE_TRAIN
EPOCH_STEP_TEST = NUM_TEST // BATCH_SIZE_TEST

logdir = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model = unet(4)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "UNET-L4-F32"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 40, 80, 1)]  0
# __________________________________________________________________________________________________
# conv2d_240 (Conv2D)             (None, 40, 80, 32)   320         input_17[0][0]
# __________________________________________________________________________________________________
# conv2d_241 (Conv2D)             (None, 40, 80, 32)   9248        conv2d_240[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_48 (MaxPooling2D) (None, 20, 40, 32)   0           conv2d_241[0][0]
# __________________________________________________________________________________________________
# conv2d_242 (Conv2D)             (None, 20, 40, 64)   18496       max_pooling2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_243 (Conv2D)             (None, 20, 40, 64)   36928       conv2d_242[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_49 (MaxPooling2D) (None, 10, 20, 64)   0           conv2d_243[0][0]
# __________________________________________________________________________________________________
# conv2d_244 (Conv2D)             (None, 10, 20, 128)  73856       max_pooling2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_245 (Conv2D)             (None, 10, 20, 128)  147584      conv2d_244[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_50 (MaxPooling2D) (None, 5, 10, 128)   0           conv2d_245[0][0]
# __________________________________________________________________________________________________
# conv2d_246 (Conv2D)             (None, 5, 10, 256)   295168      max_pooling2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_247 (Conv2D)             (None, 5, 10, 256)   590080      conv2d_246[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_48 (Conv2DTran (None, 10, 20, 128)  295040      conv2d_247[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 10, 20, 256)  0           conv2d_transpose_48[0][0]
#                                                                  conv2d_245[0][0]
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 10, 20, 128)  295040      concatenate_48[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 10, 20, 128)  147584      conv2d_248[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_49 (Conv2DTran (None, 20, 40, 64)   73792       conv2d_249[0][0]
# __________________________________________________________________________________________________
# concatenate_49 (Concatenate)    (None, 20, 40, 128)  0           conv2d_transpose_49[0][0]
#                                                                  conv2d_243[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 20, 40, 64)   73792       concatenate_49[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 20, 40, 64)   36928       conv2d_250[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_50 (Conv2DTran (None, 40, 80, 32)   18464       conv2d_251[0][0]
# __________________________________________________________________________________________________
# concatenate_50 (Concatenate)    (None, 40, 80, 64)   0           conv2d_transpose_50[0][0]
#                                                                  conv2d_241[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 40, 80, 32)   18464       concatenate_50[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 40, 80, 32)   9248        conv2d_252[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 40, 80, 32)   0           conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 40, 80, 1)    33          dropout_16[0][0]
# ==================================================================================================
# Total params: 2,140,065
# Trainable params: 2,140,065
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
begin = datetime.now()
current_time = begin.strftime("%H:%M:%S")
print("Current Time =", current_time)
    
earlyStopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=20)
model.fit_generator(generator=train_generator, 
                    steps_per_epoch=EPOCH_STEP_TRAIN, 
                    validation_data=test_generator, 
                    validation_steps=EPOCH_STEP_TEST,
                   epochs=NUM_OF_EPOCHS,callbacks=[tensorboard_callback,earlyStopping])
# Out:
# Epoch 1/500
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f959b846320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f959b846320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.2953WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f959b839680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f959b839680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 363ms/step - loss: 0.7333 - accuracy: 0.2953 - val_loss: 0.7347 - val_accuracy: 0.0929
# Epoch 2/500
# 1/1 [==============================] - ETA: 0s - loss: 0.7341 - accuracy: 0.2927WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.439091). Check your callbacks.
# 1/1 [==============================] - 0s 51ms/step - loss: 0.7341 - accuracy: 0.2927 - val_loss: 0.7273 - val_accuracy: 0.1075
# Epoch 3/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.7394 - accuracy: 0.2586 - val_loss: 0.7272 - val_accuracy: 0.1243
# Epoch 4/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7207 - accuracy: 0.3225 - val_loss: 0.7093 - val_accuracy: 0.2322
# Epoch 5/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.7156 - accuracy: 0.3601 - val_loss: 0.7199 - val_accuracy: 0.1427
# Epoch 6/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.7134 - accuracy: 0.3806 - val_loss: 0.7036 - val_accuracy: 0.2819
# Epoch 7/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.7100 - accuracy: 0.3931 - val_loss: 0.7032 - val_accuracy: 0.2062
# Epoch 8/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6986 - accuracy: 0.4687 - val_loss: 0.6973 - val_accuracy: 0.2075
# Epoch 9/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.
500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3167 - accuracy: 0.8684 - val_loss: 0.2524 - val_accuracy: 0.9091
# Epoch 474/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2768 - accuracy: 0.8838 - val_loss: 0.2605 - val_accuracy: 0.8984
# Epoch 475/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2424 - accuracy: 0.9318 - val_loss: 0.4281 - val_accuracy: 0.8583
# Epoch 476/500
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3763 - accuracy: 0.7831 - val_loss: 0.2666 - val_accuracy: 0.8828
# Epoch 477/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2548 - accuracy: 0.9197 - val_loss: 0.1862 - val_accuracy: 0.9604
# Epoch 478/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2496 - accuracy: 0.9213 - val_loss: 0.2801 - val_accuracy: 0.8767
# Epoch 479/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.2751 - accuracy: 0.8904 - val_loss: 0.3764 - val_accuracy: 0.8432
# Epoch 480/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2515 - accuracy: 0.9050 - val_loss: 0.3892 - val_accuracy: 0.8842
# Epoch 481/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2695 - accuracy: 0.8687 - val_loss: 0.2838 - val_accuracy: 0.8889
# Epoch 482/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.3216 - accuracy: 0.8388 - val_loss: 0.4522 - val_accuracy: 0.8609
# Epoch 483/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2554 - accuracy: 0.9050 - val_loss: 0.2134 - val_accuracy: 0.9290
# Epoch 484/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2865 - accuracy: 0.8722 - val_loss: 0.3677 - val_accuracy: 0.8612
# Epoch 485/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3356 - accuracy: 0.8436 - val_loss: 0.2028 - val_accuracy: 0.9162
# Epoch 486/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2936 - accuracy: 0.9068 - val_loss: 0.4725 - val_accuracy: 0.8510
# Epoch 487/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2640 - accuracy: 0.8629 - val_loss: 0.4202 - val_accuracy: 0.8967
# Epoch 488/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.3436 - accuracy: 0.8574 - val_loss: 0.5121 - val_accuracy: 0.8136
# Epoch 489/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2882 - accuracy: 0.8789 - val_loss: 0.2086 - val_accuracy: 0.9196
# Epoch 490/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2441 - accuracy: 0.8990 - val_loss: 0.2261 - val_accuracy: 0.9013
# Epoch 491/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2387 - accuracy: 0.9277 - val_loss: 0.2073 - val_accuracy: 0.9318
# Epoch 492/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.2581 - accuracy: 0.9118 - val_loss: 0.2788 - val_accuracy: 0.9140
# Epoch 493/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2758 - accuracy: 0.9046 - val_loss: 0.2742 - val_accuracy: 0.8746
# Epoch 494/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3189 - accuracy: 0.8725 - val_loss: 0.3246 - val_accuracy: 0.8445
# Epoch 495/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2725 - accuracy: 0.8958 - val_loss: 0.3497 - val_accuracy: 0.8357
# Epoch 496/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2392 - accuracy: 0.9083 - val_loss: 0.3123 - val_accuracy: 0.8825
# Epoch 497/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.3561 - accuracy: 0.8220 - val_loss: 0.3840 - val_accuracy: 0.8756
# Epoch 498/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2925 - accuracy: 0.9197 - val_loss: 0.2697 - val_accuracy: 0.9065
# Epoch 499/500
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3003 - accuracy: 0.8447 - val_loss: 0.2398 - val_accuracy: 0.9271
# Epoch 500/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3215 - accuracy: 0.8417 - val_loss: 0.3373 - val_accuracy: 0.8536

# %%
model.save(f'model/UNET-2d{IMAGE_HEIGHT}_{IMAGE_WIDTH}.h5')

# %%
test_generator =  (pair for pair in create_segmentation_generator_test(data_dir_test_image, data_dir_test_mask, 1))
# Out:
# Found 648 images belonging to 1 classes.
# Found 648 images belonging to 1 classes.

# %%
def show_prediction(datagen, num=1):
    for i in range(0,num):
        image,mask = next(datagen)
        pred_mask = model.predict(image)[0] > 0.5
        display([image[0], mask[0], pred_mask])

# %%
show_prediction(test_generator, 20)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f94e140e680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f94e140e680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import matplotlib.pyplot as plt
import numpy as np
import nibabel as nib
from niwidgets import NiftiWidget
import tensorflow as tf
from tensorflow.keras.preprocessing.image import * 
from tensorflow import keras
from config import *
from model import *
import math
import random
from tensorflow.python.framework import ops
from tensorflow.python.ops import gen_math_ops
from skimage.measure import label
import numpy as np
from skimage.util import montage, crop
from tensorflow.python.client import device_lib
from tensorflow.keras.metrics import MeanIoU,BinaryCrossentropy,Accuracy,Precision,Recall
from skimage.transform import rescale, resize, downscale_local_mean,rotate
from skimage import data, color
from scipy import ndimage
from scipy import misc
from numpy import fliplr
from datetime import *
from sklearn.model_selection import KFold
from dataAugmentation import *
import cv2
from tensorflow.keras.models import load_model
from skimage.util import random_noise
from skimage import exposure
from tensorflow.keras.losses import Reduction
from tensorflow.keras.losses import Loss

# %%
def load(task):
    model= None
    for m in os.listdir(os.path.join('model/UNET3D/',task)):
        return load_model(os.path.join('model/UNET3D/',task,m))
    return model
num=30
def show_dataset(data, num):    
    plt.figure(figsize=(15,15))
 #   file_writer = tf.summary.create_file_writer(logdir)
    for i in range(0,num):  
        i,l,pred = list(data)[i]
      #  print(labels.shape)
     #   print(l.shape)
        i=i[0]
        l=l[0]
        p = pred[0]
        fig, (ax1,ax2,ax3) = plt.subplots(1,3, figsize=(15,15))
        ax1.imshow(np.squeeze(i[num]), cmap="gray")
        ax2.imshow(np.squeeze(l[num]), cmap="gray")
        ax3.imshow(np.squeeze(p[num]), cmap="gray")
        
        
       
      
    plt.show()

# %%
model = load('segmentation')
data=[]
shape = (40, 40,40)
for d in ['mandible-Right-Molar']  :
    for niiImage in os.listdir(os.path.join(data_dir_test_image,d)):
        if niiImage=='9.10.90.nii':
            img = nib.load( os.path.join(data_dir_test_image,d, niiImage))
            inputs = normalizeImageIntensityRange(img.get_fdata() ) 
          #  inputs = exposure.equalize_hist(inputs)
            mask = np.round(nib.load( os.path.join(data_dir_test_mask,d, niiImage)).get_fdata()) 

            resize_image = resize(inputs, shape, anti_aliasing=True)
            resize_mask = resize(mask, shape, anti_aliasing=True)    
            img_np = np.rollaxis(np.array(np.array([np.array([np.array(resize_image)]) ])),0,5)
            img_mask = np.rollaxis(np.array(np.array([np.array([np.array(resize_mask)]) ])),0,5)

        # @tf.autograph.experimental.do_not_convert
            pred1 = (model.predict(img_np)).astype(float) 
            data.append([img_np,img_mask,pred1]) 
        
show_dataset(data, 11)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f967b08af80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f967b08af80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-96-54f27e88ea4b> in <module>
#      19             data.append([img_np,img_mask,pred1])
#      20
# ---> 21 show_dataset(data, 11)
#
# <ipython-input-95-9c42d87c0b7b> in show_dataset(data, num)
#       9  #   file_writer = tf.summary.create_file_writer(logdir)
#      10     for i in range(0,num):
# ---> 11         i,l,pred = list(data)[i]
#      12       #  print(labels.shape)
#      13      #   print(l.shape)
#
# IndexError: list index out of range
