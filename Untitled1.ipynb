# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('lossFunction.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,18,15,16,17,19]],axis=1)
#print(df)
#8:model,12:type 18 dice
df.columns=['Loss','Type','Specificity']

x=['Specificity']
#print(df)
data=pd.melt(df,id_vars=['Loss','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="variable",y="value",data=data,hue="Loss",palette="gist_earth_r")
boxplot2.set_xlabel("Loss functions", fontsize=14)
boxplot2.set_ylabel("Specificity", fontsize=14)
boxplot2.set(xticklabels=[])
boxplot2.set(ylim=(0.96,1.02))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["DICE", "Weighted BCE","BCE"], loc="upper left") # Associate manually the artists to a label.


boxplot2.figure.savefig('lossFunctionSpecificity.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.98704
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('lossFunction.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,20]],axis=1)
#print(df)
#8:model,12:type 18 dice
df.columns=['Loss','Type','DICE']

x=['DICE']
#print(df)
data=pd.melt(df,id_vars=['Loss','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="variable",y="value",data=data,hue="Loss",palette="gist_earth_r")
boxplot2.set_xlabel("Loss functions", fontsize=14)
boxplot2.set_ylabel("Dice coefficient", fontsize=14)
boxplot2.set(xticklabels=[])
boxplot2.set(ylim=(0.75,1.0))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["DICE", "Weighted BCE","BCE"], loc="upper left") # Associate manually the artists to a label.


boxplot2.figure.savefig('lossFunctionDice.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.846903
# dtype: float64

# %%
df = pd.read_table('dataaug2.log',',|:|-|_|.h5',header=None  ) 
#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,17,16,19,20,21,22]],axis=1)
#print(df)
#8:model,12:type
df.columns=['Model','Type','Dice']

x=['Dice']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot=sns.boxplot(x="Type",y="Dice",data=df,hue="Model",palette="gist_earth_r")
boxplot.set_xlabel("Teeth types", fontsize=14)
boxplot.set_ylabel("Dice coefficient", fontsize=14)
boxplot.set(ylim=(0.65,1.00))
handles, _ = boxplot.get_legend_handles_labels()          # Get the artists.
boxplot.legend(handles, ["Baseline", "Online data augmentation"], loc="upper left") # Associate manually the artists to a label.


#boxplot.set(xticklabels=[])

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

boxplot.figure.savefig('dataaug.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# value    0.835386
# dtype: float64

# %%
df = pd.read_table('dataaug2.log',',|:|-|_|.h5',header=None  ) 
#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,17,16,19,18,21,22]],axis=1)
#print(df)
#8:model,12:type
df.columns=['Model','Type','Specificity']

x=['Specificity']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot=sns.boxplot(x="Type",y="Specificity",data=df,hue="Model",palette="gist_earth_r")
boxplot.set_xlabel("Teeth types", fontsize=14)
boxplot.set_ylabel("Specificity", fontsize=14)
boxplot.set(ylim=(0.90,1.03))
handles, _ = boxplot.get_legend_handles_labels()          # Get the artists.
boxplot.legend(handles, ["Baseline", "Online data augmentation"], loc="upper left") # Associate manually the artists to a label.


#boxplot.set(xticklabels=[])

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

boxplot.figure.savefig('dataaugSpecificity.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# value    0.980242
# dtype: float64

# %%
df = pd.read_table('dataaug2.log',',|:|-|_|.h5',header=None  ) 
#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,17,16,19,18,20,21]],axis=1)
#print(df)
#8:model,12:type
df.columns=['Model','Type','AUC']

x=['AUC']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
#print(np.mean(data))

import seaborn as sns
boxplot=sns.boxplot(x="Type",y="AUC",data=df,hue="Model",palette="gist_earth_r")
boxplot.set_xlabel("Teeth types", fontsize=14)
boxplot.set_ylabel("AUC", fontsize=14)
boxplot.set(ylim=(0.80,1.00))
handles, _ = boxplot.get_legend_handles_labels()          # Get the artists.
boxplot.legend(handles, ["Baseline", "Online data augmentation"], loc="upper left") # Associate manually the artists to a label.

#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.legend(loc="upper left")
boxplot2.set(xticklabels=[])
boxplot.figure.savefig('dataaugAUC.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('2d3d.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,20,21,22]],axis=1)
#print(df)
#8:model,12:type 18 dice
df.columns=['Model','Type','DICE']

x=['DICE']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="Type",y="DICE",data=df,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Teeth types", fontsize=14)
boxplot2.set_ylabel("Dice coefficient", fontsize=14)
boxplot2.set(ylim=(0.50,1.02))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["2D U-Net", "3D U-Net"], loc="upper left") # Associate manually the artists to a label.

#
#boxplot2.set(xticklabels=[])
boxplot2.figure.savefig('2d3dDice.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.788851
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('2d3d.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,20,21,18]],axis=1)
#print(df)
#8:model,12:type 18 dice
df.columns=['Model','Type','AUC']

x=['AUC']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="Type",y="AUC",data=df,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Teeth types", fontsize=14)
boxplot2.set_ylabel("AUC", fontsize=14)
boxplot2.set(ylim=(0.70,1.00))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["2D U-Net", "3D U-Net"], loc="upper left") # Associate manually the artists to a label.

#boxplot2.set(xticklabels=[])
boxplot2.figure.savefig('2d3dAUC.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.85747
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('myapp.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,18,21,22]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','Specificity']

x=['Specificity']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="Type",y="Specificity",data=df,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Teeth types", fontsize=14)
boxplot2.set_ylabel("Specificity", fontsize=14)
boxplot2.set(ylim=(0.94,1.00))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

boxplot2.figure.savefig('2d3dSpecificity.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.987215
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('2d3d.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,18,21,22]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','Specificity']
sns.set_style("white")
x=['Specificity']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
#gk = df.mean()
#print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="variable",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Model", fontsize=14)
boxplot2.set_ylabel("Specificity", fontsize=14)
boxplot2.set(ylim=(0.96,1.02))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["2D U-Net", "3D U-Net"], loc="upper left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])

boxplot2.figure.savefig('2d3dFullmodelSpeci.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('2d3d.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,18,21,20]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','AUC']

x=['AUC']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x,var_name='M')
#print(data)
sns.set_style("white")
#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="M",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Model", fontsize=14)
boxplot2.set_ylabel("AUC", fontsize=14)
boxplot2.set(ylim=(0.60,1.00))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["2D U-Net", "3D U-Net"], loc="upper left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])
boxplot2.figure.savefig('2d3dFullmodelAUC.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.87054
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('2d3d.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,21,22,20]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','Dice']

x=['Dice']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x,var_name='M')
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="M",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Model", fontsize=14)
boxplot2.set_ylabel("Dice coefficient", fontsize=14)
boxplot2.set(ylim=(0.60,1.00))
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["2D U-Net", "3D U-Net"], loc="upper left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.color_palette("mako", as_cmap=True)
boxplot2.figure.savefig('2d3dFullmodelDice.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.788183
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('sparsity.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,21,22,20]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','Dice']

x=['Dice']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x,var_name='M')
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="M",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Iterations", fontsize=14)
boxplot2.set_ylabel("Dice coefficient", fontsize=14)
boxplot2.set(ylim=(0.20,0.99))
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["Iteration 1", "Iteration 2","Iteration 3","Iteration 4","Iteration 5"], loc="lower left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.color_palette("mako", as_cmap=True)
boxplot2.figure.savefig('ItertaionDice.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# Model    6.000000
# value    0.733001
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('iteration.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,21,22,18]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','Specificity']

x=['Specificity']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x,var_name='M')
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="M",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Iterations", fontsize=14)
boxplot2.set_ylabel("Specificity", fontsize=14)
boxplot2.set(ylim=(0.92,1.00))
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["Iteration 1", "Iteration 2","Iteration 3","Iteration 4","Iteration 5"], loc="lower left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.color_palette("mako", as_cmap=True)
boxplot2.figure.savefig('ItertaionSpecificity.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.98976
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('iteration.log',',|:|-|_|.h5',header=None  ) 

#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,21,20,18]],axis=1)
#print(df)
#8:model,12:type 18 dice 22 auc
df.columns=['Model','Type','AUC']

x=['AUC']
#print(df)
data=pd.melt(df,id_vars=['Model','Type'], value_vars=x,var_name='M')
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns
boxplot2=sns.boxplot(x="M",y="value",data=data,hue="Model",palette="gist_earth_r")
boxplot2.set_xlabel("Iterations", fontsize=14)
boxplot2.set_ylabel("AUC", fontsize=14)
boxplot2.set(ylim=(0.70,1.00))
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles, ["Iteration 1", "Iteration 2","Iteration 3","Iteration 4","Iteration 5"], loc="lower left") # Associate manually the artists to a label.

boxplot2.set(xticklabels=[])
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
sns.color_palette("mako", as_cmap=True)
boxplot2.figure.savefig('ItertaionAUC.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """
# value    0.860795
# dtype: float64

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(threshold=np.inf)
df = pd.read_table('sparsity.log',',|:|-|_|.h5',header=None  ) 
sns.set_style("white")
#print(df)
df=df.drop(df.columns[[0,1,2,3,4,6,7,5,9,10,11,13,14,15,16,17,19,20,21,22]],axis=1)
#print(df)
#8:model,12:type 18 dice
df.columns=['Iterations','Type','DICE']

x=['DICE']
#print(df)
data=pd.melt(df,id_vars=['Iterations','Type'], value_vars=x)
#print(data)

#lines = df.plot.box()
gk = df.mean()
print(np.mean(data))

import seaborn as sns

boxplot2=sns.boxplot(x="Type",y="DICE",data=df,hue="Iterations",palette="gist_earth_r")
boxplot2.set_xlabel("Teeth types", fontsize=14)
boxplot2.set_ylabel("Dice coefficient", fontsize=14)
boxplot2.set(ylim=(0.30,1.00))
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
handles, _ = boxplot2.get_legend_handles_labels()          # Get the artists.
boxplot2.legend(handles,  ["Iteration 1",  "Iteration 2", "Iteration 3","Iteration 4","Iteration 5"], loc="lower left") # Associate manually the artists to a label.

#
#boxplot2.set(xticklabels=[])
boxplot2.figure.savefig('iterationperteeeth.pdf')
# Out:
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# Iterations    6.000000
# value         0.733001
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_theme(style="dark")
sns.set_style("white")
x1 = np.arange(1,41,1)
y1=[0.20357971104243755, 0.15538196922426906, 0.10888298781515837, 
    0.09949103286736238, 0.061516399945894196, 0.04991738868353633,
    0.04761579998546592, 0.04016514589251019, 0.028116715951489745,
    0.02611810435403126, 0.02494486412069802, 0.019866678608797213,
    0.017970938100841983, 0.0159880248627334, 0.012653279841429266, 
    0.011353339612187728, 0.009833280124638435, 0.008632279779842144, 
    0.007652640590755823, 0.006486980077114314, 0.005986085280347475,
    0.005340982203983406, 0.004524472589290028, 0.0037573425088052617, 
    0.00353068079738604, 0.0032254520962105362, 0.0025546663081395006,
    0.0024549908111704977, 0.002159883838431885, 0.0020474533142374116,
    0.001763625623276056, 0.001381587927202078, 0.0012301562677927336, 
    0.0010168500251164251, 8.710365622558007E-4, 6.809570204082817E-4, 5.898834600845451E-4, 
    4.101920471176416E-4, 3.061398375508522E-4, 1.2421281377800364E-16
]
y1 = np.array(y1)*100
print(len(y1))
#y1= np.cumsum(y1)
x = np.arange(1,11,1)
y = [0.3303229220854239, 0.23744957759748975, 0.1386441161551237, 0.12359982652163809, 0.06669242514138014, 0.0436421963651314, 0.02692131759271677, 0.01986953485517677, 0.01285808368591922, 2.6492277643400996E-16
]
#y= np.cumsum(y)
y = np.array(y)*100
x2=np.arange(1,30,1)
y2=[0.23376292191501644, 0.16730292324671517, 0.11692247839236085, 0.10191568659913258, 0.05498884214030835, 0.04504745177827921, 0.043968661590179536, 0.03750946585439589, 0.028949745123776228, 0.02626613161165381, 0.022737614331649364, 0.02147258758100723, 0.015357218586593703, 0.013470043419670006, 0.010606742143190667, 0.009596712987254724, 0.008692035587712124, 0.007852219434842288, 0.00666867455227365, 0.006316196257732831, 0.004835254740715614, 0.0038759466246878122, 0.0027499822502352524, 0.0025064954069738835, 0.0018721963534162759, 0.0016205793745796833, 0.0014186999469768605, 9.81290492883792E-4, 7.35201675786157E-4]
#y2= np.cumsum(y2)
print(len(y2))
y2= np.array(y2)*100

x3=np.arange(1,61,1)
y3=[0.20819205435505947, 0.16253333661944785, 0.10013810487819794, 0.08344099416004461, 0.06684423411337205, 0.050330319734059874, 0.04316867857848712, 0.03530003278373487, 0.030121701783715513, 0.025481336341257942, 0.0227740393085783, 0.019138103510133914, 0.01837280448271929, 0.013926609211695643, 0.012873828805085558, 0.012468959174766685, 0.01036103058837245, 0.008776920519245047, 0.007865830179546703, 0.007263524366324753, 0.006153466155862798, 0.0058678680971495515, 0.005514446661576894, 0.004323959513044232, 0.003925933947687503, 0.003554790823969726, 0.003241170710387218, 0.003053637285408467, 0.002987836647534417, 0.0026354558486974666, 0.0023511787536949573, 0.0019047611323220754, 0.00174321127212916, 0.0016171460816457358, 0.0013662226817813265, 0.0012768994817678391, 0.001224499303425704, 0.0010051852710149772, 9.317143805147115E-4, 7.807933187258718E-4, 7.16659157669787E-4, 6.142988908564434E-4, 5.619217006033769E-4, 4.577006224783676E-4, 4.200190204743364E-4, 3.936819073927327E-4, 3.358714131111845E-4, 2.8093623921096107E-4, 2.6509241719821725E-4, 2.1838035414499193E-4, 2.0474317583015636E-4, 1.8200095820957663E-4, 1.4691935164973854E-4, 1.0883050926227695E-4, 7.149239826504614E-5, 6.24177835887579E-5, 5.385446432233077E-5, 4.826492642925329E-5, 2.4293847116248306E-5, 6.127893213068508E-17]
#y3= np.cumsum(y3)
print(len(y3))
y3= np.array(y3)*100


lplot=sns.lineplot(x, y,palette=['gist_earth_r'])
lplot=sns.lineplot(x2, y2,palette=['gist_earth_r'])
lplot=sns.lineplot(x1, y1,palette=['gist_earth_r'])
lplot=sns.lineplot(x3, y3,palette=['gist_earth_r'])

#handles, _ = plt.get_legend_handles_labels()          # Get the artists.
plt.legend( ["Model-10", "Model-30", "Model-40","Model-60"], loc="lower right") # Associate manually the artists to a label.


plt.xlabel("Number of principal components", fontsize=14)
plt.ylabel("Cumulative variance (in %)", fontsize=14)
plt.show()
lplot.figure.savefig('variancepcom.pdf')
# Out:
# 40
# 29
# 60
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#sns.set_theme(style="dark")
sns.set_style("white")
#x1 = np.arange(1,58,1)
#y1=[64092, 0.010006451822728059, 0.008873936845619554, 0.007971488798814812, 0.007592442558616818, 0.006591191446102821, 0.006487455015138414, 0.005720759253744871, 0.005471342057680001, 0.004841160592842263, 0.0041813018594842755, 0.0038393007472874606, 0.003561328278422155, 0.003188674392058766, 0.0030367168886077074, 0.0026450865160877624, 0.0024910052350242, 0.002110194106945313, 0.0019634618540527848, 0.001821460529834033, 0.0016812646027093213, 0.0014293025521839376, 0.0012376421878961743, 0.0011769221619195407, 0.0010239074774897041, 9.230517990018512E-4, 8.672497557278093E-4, 7.719090781568478E-4, 7.149658246578376E-4, 6.545648908480069E-4, 5.652681331364055E-4, 5.404633565672275E-4, 4.55578791186769E-4, 4.1215433798980853E-4, 3.4412929655480316E-4, 3.051585576324613E-4, 2.5876579184215065E-4, 2.346302384225979E-4, 2.09494901199922E-4, 1.4956882842988056E-4]
#y1 = np.array(y1)*100
#print(len(y1))
df = pd.read_table('metrics.log',':|#',header=None) 
#print(df)
df=df.drop(df.columns[[0,2]],axis=1)
print(df)
df.columns=['Sample','error']

x = np.arange(1,10,1)
#data = {'x': x,'y':y}
#plt.subplot(411)
#boxplot2=sns.pointplot(y='error',data=df,palette="gist_earth_r")

#lplot=plt.plot(x,y)

#plt.subplot(412)
#lplot=plt.plot(x1, y1)
#plt.subplot(413)
#lplot=plt.plot(x5, y5)
#plt.subplot(414)
#lplot=plt.plot(x2, y2)

#handles, _ = plt.get_legend_handles_labels()          # Get the artists.
#plt.legend( ["Model-10","Model-30","Model-40","Model-60"], loc="upper right") # Associate manually the artists to a label.

fig, ax = plt.subplots()
  
for key, group in df.groupby('Sample'):
    group.plot('Sample', 'mean', yerr='std', label=key, ax=ax)
  
    plt.show()
    plt.xlabel("Number of principal components", fontsize=14)
    plt.ylabel("Generalization (in mm)", fontsize=14)
    plt.show()
#lplot.figure.savefig('generpercomp.pdf')
# Out:
#        1                                                  3
# 0   '1'   0.08207644937202063,0.5386966713715857,0.92751...
# /home/jain0000/miniconda3/envs/segment2/lib/python3.7/site-packages/ipykernel_launcher.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # Remove the CWD from sys.path while we load stuff.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/segment2/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# ...
